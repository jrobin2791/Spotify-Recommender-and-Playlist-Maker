# %% [markdown]
# # Data Munging and Modeling

# %% [markdown]
# The following code shows the process for cleaning and processing data from a series of songs into a list that is sorted by similarity to a reference song. In this case, we have a sample of 194 songs, one of which is our reference song, "Clocks" by Coldplay.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ## Data

# %%
tracks = pd.read_csv('./data/tracks.csv')
tracks.head()
# Out:
#                                   name  acousticness  \
# 0                               Clocks        0.5990
# 1  Stranger Things (feat. OneRepublic)        0.2340
# 2         Save Tonight (feat. Solamay)        0.2920
# 3                      Burning Bridges        0.0510
# 4                            My Shadow        0.0222
#
#                                         analysis_url        artist  \
# 0  https://api.spotify.com/v1/audio-analysis/0BCP...      Coldplay
# 1  https://api.spotify.com/v1/audio-analysis/4sJq...          Kygo
# 2  https://api.spotify.com/v1/audio-analysis/2PWK...  Robin Schulz
# 3  https://api.spotify.com/v1/audio-analysis/3qd6...   OneRepublic
# 4  https://api.spotify.com/v1/audio-analysis/7f20...         Keane
#
#    danceability  duration_ms  energy         genre_1 genre_10  \
# 0         0.577       307880   0.749  permanent wave      NaN
# 1         0.604       221440   0.661             edm      NaN
# 2         0.631       216933   0.740       dance pop      NaN
# 3         0.579       257573   0.739       dance pop      NaN
# 4         0.490       289360   0.416      neo mellow      NaN
#
#            genre_2   ...    mode n_genres popularity speechiness    tempo  \
# 0              pop   ...       0        2         75      0.0279  130.969
# 1              pop   ...       1        3         69      0.0375  107.016
# 2  deep euro house   ...       1        6         55      0.1120  121.962
# 3       neo mellow   ...       1        7         47      0.0258   97.976
# 4       piano rock   ...       1        4         43      0.0301   98.135
#
#   time_signature                                         track_href  \
# 0              4  https://api.spotify.com/v1/tracks/0BCPKOYdS2jb...
# 1              4  https://api.spotify.com/v1/tracks/4sJqSKPc5fZ5...
# 2              4  https://api.spotify.com/v1/tracks/2PWKdiDjYkkO...
# 3              4  https://api.spotify.com/v1/tracks/3qd6wKpFQf4J...
# 4              4  https://api.spotify.com/v1/tracks/7f208BAaf1Hw...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:0BCPKOYdS2jbQ8iyB56Zns   0.2610
# 1  audio_features  spotify:track:4sJqSKPc5fZ5OZ8JiVI44N   0.5060
# 2  audio_features  spotify:track:2PWKdiDjYkkOdInPxGrP51   0.3960
# 3  audio_features  spotify:track:3qd6wKpFQf4JljGU7y18CJ   0.2350
# 4  audio_features  spotify:track:7f208BAaf1Hw1dCKBwZe8M   0.0449
#
# [5 rows x 32 columns]

# %%
tracks.shape
# Out:
# (194, 32)

# %%
# The reference song
tracks[(tracks['artist'] == 'Coldplay')]
# Out:
#      name  acousticness                                       analysis_url  \
# 0  Clocks         0.599  https://api.spotify.com/v1/audio-analysis/0BCP...
#
#      artist  danceability  duration_ms  energy         genre_1 genre_10  \
# 0  Coldplay         0.577       307880   0.749  permanent wave      NaN
#
#   genre_2   ...    mode n_genres popularity speechiness    tempo  \
# 0     pop   ...       0        2         75      0.0279  130.969
#
#   time_signature                                         track_href  \
# 0              4  https://api.spotify.com/v1/tracks/0BCPKOYdS2jb...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:0BCPKOYdS2jbQ8iyB56Zns    0.261
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Cleaning

# %%
# Drop duplicate songs
tracks.drop_duplicates(subset='name', inplace=True)

# %%
# Index by song titles
tracks.set_index('name', inplace=True)

# %%
# A list of features to use in a model
features_list = ['acousticness', 
                 'danceability', 
                 'energy', 
                 'instrumentalness', 
                 'liveness', 
                 'loudness', 
                 'mode', 
                 'popularity', 
                 'speechiness', 
                 'tempo', 
                 'time_signature', 
                 'valence']

# %% [markdown]
# The number of genres under a given song can range anywhere from 1 to over 10 different genres. For this reason there are multiple columns for 'genre_1', 'genre_2', etc. up to the whatever song has the most genres in the dataframe. This also means that there are lots of blank values in the higher columns for songs with less genres. The end goal in cleaning up all of this genre information is to find all the unique genres that exist in the entire dataframe, and make a consolidated column for each of those genres. This way each song will have a 1 under each genre that it belongs to and a 0 for any genre it does not belong to.

# %%
# This list will become a set of all the genres that exist in the dataframe
genre_set = []
# Loop through each genre column
for i in range(tracks['n_genres'].max()):
    # Add all the genres that exist in the column to the total list of genres
    genre_set.extend(tracks[f'genre_{i + 1}'].unique())
    # Create dummy columns from the original genre column
    tracks = pd.get_dummies(tracks, columns=[f'genre_{i + 1}'])

# Convert the total list to a set of unique genres
genre_set = set(genre_set)
# Remove the null value in this set
genre_set.remove(np.nan)
genre_set
# Out:
# {'acoustic pop',
#  'alternative dance',
#  'alternative rock',
#  'ambient worship',
#  'art rock',
#  'australian dance',
#  'australian electropop',
#  'australian pop',
#  'big room',
#  'boy band',
#  'britpop',
#  'celtic rock',
#  'chamber pop',
#  'dance pop',
#  'dance-punk',
#  'deep euro house',
#  'deep house',
#  'downtempo',
#  'dream pop',
#  'edm',
#  'electro house',
#  'electropop',
#  'europop',
#  'folk-pop',
#  'gauze pop',
#  'indie anthem-folk',
#  'indie folk',
#  'indie pop',
#  'indie rock',
#  'indietronica',
#  'irish pop',
#  'irish rock',
#  'latin alternative',
#  'latin rock',
#  'melancholia',
#  'metropopolis',
#  'mexican rock',
#  'modern rock',
#  'neo mellow',
#  'neo-singer-songwriter',
#  'neo-synthpop',
#  'new rave',
#  'new wave pop',
#  'oxford indie',
#  'permanent wave',
#  'piano rock',
#  'pop',
#  'pop rap',
#  'pop rock',
#  'post-grunge',
#  'post-teen pop',
#  'progressive electro house',
#  'rock',
#  'rock en espanol',
#  'singer-songwriter',
#  'stomp and holler',
#  'tropical house',
#  'uk pop',
#  'viral pop'}

# %%
# Loop through each unique genre
for genre in genre_set:
    # A list to store all column names that belong to a specific genre
    same_genre_cols = []
    # Loop through columns in the dataframe
    for col in tracks.columns:
        # Filter only the genre dummy columns
        if col[:5] == 'genre':
            # Filter only the columns which begin with genre_1 through genre_9
            if col[7] == '_':
                # Filter only the columns which are part of the unique genre
                if genre == col[8:]:
                    # Add those column names to same_genre_cols
                    same_genre_cols.append(col)

            # Filter only the columns which begin with genre_10 or higher
            else:
                # Filter only the columns which are part of the unique genre
                if genre == col[9:]:
                    # Add those column names to same_genre_cols
                    same_genre_cols.append(col)
    
    # Create a new column of all zeros for the unique genre
    tracks[genre] = 0
    # Loop through the columns belonging to that genre
    for col in same_genre_cols:
        # Add the each column to the final genre column
        tracks[genre] += tracks[col]
    
    # Add the name of the newly compiled genre column to the features list
    features_list.append(genre)

# %% [markdown]
# ## Preprocessing

# %%
# A datframe with only the relevent features
model_data = tracks[features_list]
model_data.head()
# Out:
#                                      acousticness  danceability  energy  \
# name
# Clocks                                     0.5990         0.577   0.749
# Stranger Things (feat. OneRepublic)        0.2340         0.604   0.661
# Save Tonight (feat. Solamay)               0.2920         0.631   0.740
# Burning Bridges                            0.0510         0.579   0.739
# My Shadow                                  0.0222         0.490   0.416
#
#                                      instrumentalness  liveness  loudness  \
# name
# Clocks                                       0.011200    0.1830    -7.215
# Stranger Things (feat. OneRepublic)          0.000000    0.0951    -5.914
# Save Tonight (feat. Solamay)                 0.000000    0.2440    -6.206
# Burning Bridges                              0.000000    0.0830    -5.266
# My Shadow                                    0.000095    0.0938    -8.025
#
#                                      mode  popularity  speechiness    tempo  \
# name
# Clocks                                  0          75       0.0279  130.969
# Stranger Things (feat. OneRepublic)     1          69       0.0375  107.016
# Save Tonight (feat. Solamay)            1          55       0.1120  121.962
# Burning Bridges                         1          47       0.0258   97.976
# My Shadow                               1          43       0.0301   98.135
#
#                                          ...       indie rock  irish pop  \
# name                                     ...
# Clocks                                   ...                0          0
# Stranger Things (feat. OneRepublic)      ...                0          0
# Save Tonight (feat. Solamay)             ...                0          0
# Burning Bridges                          ...                0          0
# My Shadow                                ...                0          0
#
#                                      boy band  electro house  pop rap  \
# name
# Clocks                                      0              0        0
# Stranger Things (feat. OneRepublic)         0              0        0
# Save Tonight (feat. Solamay)                0              0        0
# Burning Bridges                             0              0        1
# My Shadow                                   0              0        0
#
#                                      neo-singer-songwriter  \
# name
# Clocks                                                   0
# Stranger Things (feat. OneRepublic)                      0
# Save Tonight (feat. Solamay)                             0
# Burning Bridges                                          0
# My Shadow                                                0
#
#                                      australian electropop  celtic rock  \
# name
# Clocks                                                   0            0
# Stranger Things (feat. OneRepublic)                      0            0
# Save Tonight (feat. Solamay)                             0            0
# Burning Bridges                                          0            0
# My Shadow                                                0            0
#
#                                      australian dance  acoustic pop
# name
# Clocks                                              0             0
# Stranger Things (feat. OneRepublic)                 0             0
# Save Tonight (feat. Solamay)                        0             0
# Burning Bridges                                     0             0
# My Shadow                                           0             0
#
# [5 rows x 71 columns]

# %%
# Scale the popularity ratings between 0 and 1
model_data['popularity'] = model_data['popularity'] / 100

# %%
# Scale the time_signature, tempo, and loudness between 0 and 1
minmax = MinMaxScaler()
model_data[['time_signature', 'tempo', 'loudness']] = minmax.fit_transform(model_data[['time_signature', 'tempo', 'loudness']])
model_data.head()
# Out:
#                                      acousticness  danceability  energy  \
# name
# Clocks                                     0.5990         0.577   0.749
# Stranger Things (feat. OneRepublic)        0.2340         0.604   0.661
# Save Tonight (feat. Solamay)               0.2920         0.631   0.740
# Burning Bridges                            0.0510         0.579   0.739
# My Shadow                                  0.0222         0.490   0.416
#
#                                      instrumentalness  liveness  loudness  \
# name
# Clocks                                       0.011200    0.1830  0.522962
# Stranger Things (feat. OneRepublic)          0.000000    0.0951  0.675375
# Save Tonight (feat. Solamay)                 0.000000    0.2440  0.641167
# Burning Bridges                              0.000000    0.0830  0.751289
# My Shadow                                    0.000095    0.0938  0.428069
#
#                                      mode  popularity  speechiness     tempo  \
# name
# Clocks                                  0        0.75       0.0279  0.518852
# Stranger Things (feat. OneRepublic)     1        0.69       0.0375  0.329993
# Save Tonight (feat. Solamay)            1        0.55       0.1120  0.447836
# Burning Bridges                         1        0.47       0.0258  0.258716
# My Shadow                               1        0.43       0.0301  0.259970
#
#                                          ...       indie rock  irish pop  \
# name                                     ...
# Clocks                                   ...                0          0
# Stranger Things (feat. OneRepublic)      ...                0          0
# Save Tonight (feat. Solamay)             ...                0          0
# Burning Bridges                          ...                0          0
# My Shadow                                ...                0          0
#
#                                      boy band  electro house  pop rap  \
# name
# Clocks                                      0              0        0
# Stranger Things (feat. OneRepublic)         0              0        0
# Save Tonight (feat. Solamay)                0              0        0
# Burning Bridges                             0              0        1
# My Shadow                                   0              0        0
#
#                                      neo-singer-songwriter  \
# name
# Clocks                                                   0
# Stranger Things (feat. OneRepublic)                      0
# Save Tonight (feat. Solamay)                             0
# Burning Bridges                                          0
# My Shadow                                                0
#
#                                      australian electropop  celtic rock  \
# name
# Clocks                                                   0            0
# Stranger Things (feat. OneRepublic)                      0            0
# Save Tonight (feat. Solamay)                             0            0
# Burning Bridges                                          0            0
# My Shadow                                                0            0
#
#                                      australian dance  acoustic pop
# name
# Clocks                                              0             0
# Stranger Things (feat. OneRepublic)                 0             0
# Save Tonight (feat. Solamay)                        0             0
# Burning Bridges                                     0             0
# My Shadow                                           0             0
#
# [5 rows x 71 columns]

# %% [markdown]
# ## Modeling

# %%
# Convert the dataframe to a sparse matrix
tracks_sparse = sparse.csr_matrix(model_data)
# Calculate the cosine similarity between each song
recommender = pairwise_distances(tracks_sparse, metric='cosine')
# Convert the results to a dataframe
recommender_df = pd.DataFrame(recommender, columns=model_data.index, index=model_data.index)
recommender_df.head()
# Out:
# name                                   Clocks  \
# name
# Clocks                               0.000000
# Stranger Things (feat. OneRepublic)  0.356805
# Save Tonight (feat. Solamay)         0.458474
# Burning Bridges                      0.523509
# My Shadow                            0.668838
#
# name                                 Stranger Things (feat. OneRepublic)  \
# name
# Clocks                                                          0.356805
# Stranger Things (feat. OneRepublic)                             0.000000
# Save Tonight (feat. Solamay)                                    0.173444
# Burning Bridges                                                 0.466076
# My Shadow                                                       0.567497
#
# name                                 Save Tonight (feat. Solamay)  \
# name
# Clocks                                                   0.458474
# Stranger Things (feat. OneRepublic)                      0.173444
# Save Tonight (feat. Solamay)                             0.000000
# Burning Bridges                                          0.456216
# My Shadow                                                0.638686
#
# name                                 Burning Bridges  My Shadow   Fake It  \
# name
# Clocks                                      0.523509   0.668838  0.296777
# Stranger Things (feat. OneRepublic)         0.466076   0.567497  0.409591
# Save Tonight (feat. Solamay)                0.456216   0.638686  0.501072
# Burning Bridges                             0.000000   0.293379  0.545375
# My Shadow                                   0.293379   0.000000  0.685834
#
# name                                 Keep on Walking  Corazón Atómico  \
# name
# Clocks                                      0.584784         0.540068
# Stranger Things (feat. OneRepublic)         0.533171         0.633259
# Save Tonight (feat. Solamay)                0.521431         0.693000
# Burning Bridges                             0.470167         0.737672
# My Shadow                                   0.603685         0.748390
#
# name                                 Here's To Us  Higher Than The Sun  \
# name
# Clocks                                   0.462764             0.584541
# Stranger Things (feat. OneRepublic)      0.408747             0.508981
# Save Tonight (feat. Solamay)             0.393459             0.586684
# Burning Bridges                          0.430403             0.296680
# My Shadow                                0.762543             0.046323
#
# name                                               ...                 \
# name                                               ...
# Clocks                                             ...
# Stranger Things (feat. OneRepublic)                ...
# Save Tonight (feat. Solamay)                       ...
# Burning Bridges                                    ...
# My Shadow                                          ...
#
# name                                 Stop For A Minute     Hielo  Who Am I  \
# name
# Clocks                                        0.572466  0.551840  0.340328
# Stranger Things (feat. OneRepublic)           0.613521  0.622392  0.451092
# Save Tonight (feat. Solamay)                  0.682847  0.687031  0.540492
# Burning Bridges                               0.355334  0.732858  0.479292
# My Shadow                                     0.125809  0.745485  0.580525
#
# name                                 Lend Me Some Light   Red Eye  The Driver  \
# name
# Clocks                                         0.576059  0.450390    0.354560
# Stranger Things (feat. OneRepublic)            0.536534  0.387045    0.438400
# Save Tonight (feat. Solamay)                   0.608877  0.487250    0.532084
# Burning Bridges                                0.639796  0.402216    0.560047
# My Shadow                                      0.711265  0.455696    0.709223
#
# name                                 Looking Back  Infinito - Live  \
# name
# Clocks                                   0.543407         0.614317
# Stranger Things (feat. OneRepublic)      0.610339         0.541588
# Save Tonight (feat. Solamay)             0.665936         0.606291
# Burning Bridges                          0.381381         0.643526
# My Shadow                                0.161680         0.609056
#
# name                                 Bend & Break  \
# name
# Clocks                                   0.559869
# Stranger Things (feat. OneRepublic)      0.478555
# Save Tonight (feat. Solamay)             0.567017
# Burning Bridges                          0.276917
# My Shadow                                0.045919
#
# name                                 Torn Apart (Bastille Vs. GRADES)
# name
# Clocks                                                       0.323780
# Stranger Things (feat. OneRepublic)                          0.427203
# Save Tonight (feat. Solamay)                                 0.515232
# Burning Bridges                                              0.552874
# My Shadow                                                    0.695295
#
# [5 rows x 194 columns]

# %% [markdown]
# Now that we have all the cosine similarities, we can rank all the songs by their similarity to "Clocks" by Coldplay.

# %%
# Create a list ordering the songs by how similar they are to the reference song
ranked_choices = recommender_df['Clocks'].sort_values()[1:]

# %%
# Final result
ranked_choices
# Out:
# name
# Leaving It Up to You                                             0.242107
# Hold My Girl                                                     0.279054
# Sugarcoat                                                        0.287675
# Four Walls (The Ballad Of Perry Smith)                           0.287968
# Fake It                                                          0.296777
# Go Gentle                                                        0.300129
# Wonder of the World                                              0.302137
# Pretty Shining People                                            0.302926
# Stupid Love Song - 2006 Demo                                     0.304166
# Things We Lost In The Fire                                       0.305939
# Way Back When                                                    0.306193
# These Streets                                                    0.310803
# An Act Of Kindness                                               0.310846
# Secret Tattoo                                                    0.317070
# The Draw                                                         0.319714
# Torn Apart (Bastille Vs. GRADES)                                 0.323780
# Icarus                                                           0.324047
# Laughter Lines                                                   0.324736
# Barcelona                                                        0.327281
# bad_news (Bastille Vs. MNEK)                                     0.328355
# Quarter Past Midnight                                            0.330233
# With You (feat. Wrabel)                                          0.338876
# Grow Old with Me                                                 0.339768
# Who Am I                                                         0.340328
# Sleepsong                                                        0.341750
# The District Sleeps Alone Tonight                                0.349516
# Flaws                                                            0.351534
# Give Me Strength                                                 0.354157
# The Driver                                                       0.354560
# Pompeii                                                          0.354604
#                                                                    ...
# Andrómeda                                                        0.586987
# She Has No Time                                                  0.587178
# Won't Be Broken                                                  0.590448
# She Will Sing                                                    0.593310
# Pure Morning                                                     0.594917
# Untitled 1                                                       0.595758
# Snowed Under                                                     0.596765
# In Your Own Time                                                 0.598140
# Sombras - Live                                                   0.598822
# Thin Air                                                         0.599766
# November                                                         0.603547
# Watch How You Go                                                 0.604461
# Bedshaped                                                        0.607272
# Atlantic                                                         0.609334
# Evaporate                                                        0.612418
# Infinito - Live                                                  0.614317
# Stubborn Love                                                    0.615659
# Fantasma                                                         0.617029
# 1904                                                             0.617123
# Numb                                                             0.618392
# Your Love                                                        0.618433
# Paula                                                            0.619836
# A Heart To Hold You - Jo Whiley Show - BBC Session 24/11/2004    0.620558
# Where You Stand                                                  0.626407
# Sovereign Light Café                                             0.628933
# Box Of Stones                                                    0.631067
# Look Ma!                                                         0.639547
# What If I'm Wrong                                                0.665023
# We Might As Well Be Strangers                                    0.665717
# My Shadow                                                        0.668838
# Name: Clocks, Length: 193, dtype: float64
